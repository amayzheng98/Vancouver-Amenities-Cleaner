# %%
import pandas as pd
import numpy as np

# %%
amenities = pd.read_json("amenities-vancouver.json.gz", lines=True)

# %% [markdown]
# We can filter out places that do not have a name since all restaurants should have a name

# %%
places = amenities.dropna()
places
# Out:
#              lat         lon                      timestamp           amenity  \
# 0      49.260812 -123.125736  2020-03-20T18:22:12.000-07:00              cafe
# 1      49.260953 -123.125704  2019-08-02T18:11:20.000-07:00         fast_food
# 4      49.370898 -123.280448  2015-05-03T00:42:25.000-07:00  place_of_worship
# 7      49.264041 -123.153407  2019-08-29T18:50:05.000-07:00              fuel
# 13     49.126650 -123.182470  2020-03-30T09:08:51.000-07:00        restaurant
# ...          ...         ...                            ...               ...
# 17712  49.250408 -123.076261  2017-07-08T05:22:57.000-07:00        restaurant
# 17713  49.278424 -122.806704  2013-03-26T23:45:49.000-07:00              cafe
# 17714  49.278770 -122.797628  2013-03-26T23:45:49.000-07:00        restaurant
# 17716  49.282666 -122.826978  2019-09-13T13:56:49.000-07:00               pub
# 17717  49.282420 -122.826340  2019-09-13T13:56:49.000-07:00              cafe
#
#                                name  \
# 0                         Starbucks
# 1                        Salad Loop
# 4      St. Monica's Anglican Church
# 7                             Shell
# 13         Best Bite Indian Cuisine
# ...                             ...
# 17712                House of Dosas
# 17713              Creekside Coffee
# 17714                    Togo Sushi
# 17716          Brown's Social House
# 17717              Gallagher's Cafe
#
#                                                     tags
# 0      {'brand:wikidata': 'Q37158', 'official_name': ...
# 1      {'opening_hours': 'Mo-Fr 07:00-17:00; Sa 10:00...
# 4      {'addr:housenumber': '6404', 'addr:street': 'W...
# 7      {'brand:wikidata': 'Q154950', 'addr:housenumbe...
# 13     {'addr:housenumber': '10-3891', 'phone': '+1-6...
# ...                                                  ...
# 17712  {'addr:housenumber': '1391', 'phone': '+1-604-...
# 17713                                                 {}
# 17714                            {'cuisine': 'japanese'}
# 17716  {'addr:housenumber': '215', 'brewery': 'Guinne...
# 17717  {'addr:housenumber': '232', 'internet_access':...
#
# [8169 rows x 6 columns]

# %% [markdown]
# Inspecting all the tags in case something important pops up

# %%
all_tags = places['tags'].values

# %% [markdown]
# Going to extract all unique keys in dictionaries

# %%
all_keys = {x for dict_keys in all_tags for x in dict_keys}
all_keys
# Out:
# {'access',
#  'addr:city',
#  'addr:country',
#  'addr:flats',
#  'addr:housename',
#  'addr:housenumber',
#  'addr:interpolation',
#  'addr:postcode',
#  'addr:province',
#  'addr:street',
#  'addr:town',
#  'addr:unit',
#  'after_school',
#  'age_group',
#  'air_conditioning',
#  'alt',
#  'alt_name',
#  'alt_name:en',
#  'alt_name:vi',
#  'amenity:cafe',
#  'amenity:ice_cream',
#  'amenity_2',
#  'animal_shelter',
#  'artist_name',
#  'artwork_type',
#  'atm',
#  'authentication',
#  'automated',
#  'backrest',
#  'bar',
#  'bench',
#  'bicycle_parking',
#  'bin',
#  'bottle',
#  'brand',
#  'brand:en',
#  'brand:fr',
#  'brand:wikidata',
#  'brand:wikipedia',
#  'brand:zh',
#  'brewery',
#  'building',
#  'building:levels',
#  'bus',
#  'capacity',
#  'car',
#  'cargo',
#  'category',
#  'changing_table',
#  'city',
#  'club',
#  'cocktails',
#  'cold_water',
#  'collection_times',
#  'colour',
#  'community:gender',
#  'construction',
#  'contact:email',
#  'contact:facebook',
#  'contact:google_plus',
#  'contact:instagram',
#  'contact:linkedin',
#  'contact:phone',
#  'contact:twitter',
#  'contact:website',
#  'contact:yelp',
#  'contact:youtube',
#  'covered',
#  'craft',
#  'created_by',
#  'cuisine',
#  'cuisine:japanese',
#  'cuisine:seafood',
#  'cuisine:steak_house',
#  'cuisine:sushi',
#  'currency:AUD',
#  'currency:CAD',
#  'currency:CHF',
#  'currency:DKK',
#  'currency:EUR',
#  'currency:GBP',
#  'currency:HUF',
#  'currency:JPY',
#  'currency:MXN',
#  'currency:PLN',
#  'currency:RUB',
#  'currency:THB',
#  'currency:USD',
#  'currency:XBT',
#  'currency:others',
#  'cusine',
#  'dance:teaching',
#  'date',
#  'delivery',
#  'denomination',
#  'description',
#  'designation',
#  'diet:dairy_free',
#  'diet:gluten_free',
#  'diet:halal',
#  'diet:lactose_free',
#  'diet:meat',
#  'diet:organic',
#  'diet:paleo',
#  'diet:vegan',
#  'diet:vegetarian',
#  'dispensing',
#  'display',
#  'distributor',
#  'disused',
#  'disused:amenity',
#  'disused:craft',
#  'drink',
#  'drink:juice',
#  'drinking_water',
#  'drive_in',
#  'drive_through',
#  'education',
#  'ele',
#  'email',
#  'emergency',
#  'entrance',
#  'facebook',
#  'faces',
#  'fast_food',
#  'fax',
#  'fee',
#  'ferry',
#  'ferry_terminal',
#  'fixme',
#  'food',
#  'fountain',
#  'fuel',
#  'fuel:biodiesel',
#  'fuel:biogas',
#  'fuel:diesel',
#  'fuel:electricity',
#  'fuel:gasoline',
#  'fuel:lpg',
#  'fuel:octane_87',
#  'fuel:octane_89',
#  'fuel:octane_91',
#  'fuel:octane_94',
#  'fuel:octane_95',
#  'fuel:propane',
#  'ground',
#  'guide',
#  'happy_hours',
#  'haunted',
#  'healthcare',
#  'healthcare:centre',
#  'healthcare:counselling',
#  'healthcare:speciality',
#  'healthcare:speciality:acupuncture',
#  'healthcare:speciality:chiropractic',
#  'healthcare:speciality:naturopathy',
#  'highway',
#  'historic',
#  'image',
#  'indoor',
#  'industrial',
#  'information',
#  'inscription',
#  'int_name',
#  'internet',
#  'internet_access',
#  'internet_access:fee',
#  'internet_access:ssid',
#  'is_in:city',
#  'kindergarten',
#  'landuse',
#  'language:en',
#  'layer',
#  'leisure',
#  'level',
#  'lit',
#  'loc_name',
#  'material',
#  'maxstay',
#  'membership',
#  'memorial',
#  'microbrewery',
#  'monastery:type',
#  'musical_instrument:teaching',
#  'name:de',
#  'name:en',
#  'name:es',
#  'name:fi',
#  'name:fr',
#  'name:hu',
#  'name:it',
#  'name:ko',
#  'name:nl',
#  'name:vi',
#  'name:zh',
#  'name:zh_pinyin',
#  'name_alt',
#  'network',
#  'note',
#  'note:fr',
#  'notes',
#  'office',
#  'official_name',
#  'official_name:en',
#  'official_name:fr',
#  'old_name',
#  'old_website',
#  'opening_date',
#  'opening_hours',
#  'opening_hours:covid19',
#  'opening_hours:signed',
#  'opening_hours:url',
#  'operator',
#  'operator:type',
#  'operator:wikidata',
#  'operator:wikipedia',
#  'outdoor_seating',
#  'outdoor_seating:comfort',
#  'owner',
#  'park_ride',
#  'parking',
#  'payment',
#  'payment:american_express',
#  'payment:bitcoin',
#  'payment:cash',
#  'payment:cheque',
#  'payment:coinkite',
#  'payment:contactless',
#  'payment:credit_card',
#  'payment:credit_cards',
#  'payment:debit_cards',
#  'payment:discover_card',
#  'payment:financing',
#  'payment:mastercard',
#  'payment:subscription',
#  'payment:visa',
#  'phone',
#  'phone:CA',
#  'phone_1',
#  'photo',
#  'post_office:brand',
#  'post_office:brand:wikidata',
#  'post_office:brand:wikipedia',
#  'post_office:operator',
#  'postal_code',
#  'preschool',
#  'product',
#  'public_transport',
#  'recycling:batteries',
#  'recycling:beverage_cartons',
#  'recycling:cans',
#  'recycling:cardboard',
#  'recycling:cars',
#  'recycling:clothes',
#  'recycling:electrical_items',
#  'recycling:electronics',
#  'recycling:glass',
#  'recycling:glass_bottles',
#  'recycling:low_energy_bulbs',
#  'recycling:paint',
#  'recycling:paper',
#  'recycling:plastic',
#  'recycling:plastic_bags',
#  'recycling:plastic_bottles',
#  'recycling:scrap_metal',
#  'recycling:small_appliances',
#  'recycling_type',
#  'ref',
#  'ref:isil',
#  'religion',
#  'rental',
#  'reservation',
#  'screen',
#  'seasonal',
#  'seating',
#  'seats',
#  'second_hand',
#  'self_service',
#  'service',
#  'service_times',
#  'shelter',
#  'shop',
#  'shop:computer',
#  'shop:confectionery',
#  'shop:electronics',
#  'shop:gift',
#  'shop:photo',
#  'short_name',
#  'smoking',
#  'smoothness',
#  'social_facility',
#  'social_facility:for',
#  'socket:chademo',
#  'socket:tesla_supercharger:output',
#  'socket:type1',
#  'source',
#  'source:addr',
#  'source:location',
#  'source:name',
#  'source:name:url',
#  'source:position',
#  'speciality',
#  'specialty',
#  'sport',
#  'start_date',
#  'studio',
#  'supervised',
#  'support',
#  'surface',
#  'surrey:addrid',
#  'surrey:date',
#  'surveillance',
#  'survey:date',
#  'tactile_paving',
#  'takeaway',
#  'takeaway:covid19',
#  'theatre:genre',
#  'toilets',
#  'toilets:disposal',
#  'toilets:wheelchair',
#  'tourism',
#  'type',
#  'unisex',
#  'unit',
#  'url',
#  'vending',
#  'visibility',
#  'waste',
#  'website',
#  'website:fr',
#  'wheelchair',
#  'wheelchair:description',
#  'wifi',
#  'wikidata',
#  'wikipedia',
#  'wikipedia:en',
#  'wlan',
#  'yelp'}

# %%
Nothing clear cut for cuisine since we found this list  
 'cuisine',  
 'cuisine:japanese',  
 'cuisine:seafood',  
 'cuisine:steak_house',  
 'cuisine:sushi',  
 'cusine'  
Chain restaurants are the same as some entries have no tags ex:A&W

# %%
amenities['amenity'].unique()
# Out:
# array(['cafe', 'fast_food', 'toilets', 'bbq', 'place_of_worship',
#        'post_box', 'telephone', 'fuel', 'vending_machine', 'restaurant',
#        'parking_entrance', 'pub', 'bicycle_parking', 'school', 'bench',
#        'community_centre', 'waste_basket', 'pharmacy', 'dentist',
#        'doctors', 'post_office', 'atm', 'childcare', 'parking',
#        'public_building', 'bank', 'cinema', 'theatre', 'ferry_terminal',
#        'bar', 'library', 'car_rental', 'drinking_water', 'shelter',
#        'car_sharing', 'bicycle_rental', 'clinic', 'recycling',
#        'public_bookcase', 'university', 'dojo', 'food_court',
#        'seaplane terminal', 'arts_centre', 'ice_cream',
#        'charging_station', 'car_wash', 'fountain', 'veterinary',
#        'bicycle_repair_station', 'waste_disposal', 'photo_booth',
#        'luggage_locker', 'bureau_de_change', 'parking_space', 'nightclub',
#        'social_facility', 'taxi', 'bus_station', 'college',
#        'construction', 'post_depot', 'nursery', 'clock', 'kindergarten',
#        'conference_centre', 'shower', 'marketplace', 'hospital',
#        'trolley_bay', 'fire_station', 'police', 'motorcycle_parking',
#        'stripclub', 'gambling', 'compressed_air', 'family_centre',
#        'townhall', 'music_school', 'bistro', 'playground', 'boat_rental',
#        'meditation_centre', 'spa', 'scrapyard', 'language_school',
#        'courthouse', 'events_venue', 'prep_school', 'healthcare',
#        'cram_school', 'science', 'ATLAS_clean_room', 'workshop', 'safety',
#        'lobby', 'animal_shelter', 'juice_bar', 'internet_cafe',
#        'social_centre', 'vacuum_cleaner', 'smoking_area', 'EVSE',
#        'studio', 'first_aid', 'ranger_station', 'storage_rental',
#        'watering_place', 'lounge', 'trash', 'sanitary_dump_station',
#        'disused:restaurant', 'water_point', 'Observation Platform',
#        'housing co-op', 'driving_school', 'loading_dock', 'chiropractor',
#        'monastery', 'storage', 'gym', 'payment_terminal', 'atm;bank',
#        'park', 'biergarten', 'casino', 'Pharmacy',
#        'waste_transfer_station', 'office|financial', 'hunting_stand',
#        'money_transfer', 'shop|clothes', 'letter_box', 'training',
#        'car_rep', 'research_institute', 'motorcycle_rental', 'leisure'],
#       dtype=object)

# %% [markdown]
# From the amenities column we can manually select amenities to filter to just places to eat

# %%
food_list = [
    'cafe', 'fast_food', 'bbq', 'restaurant', 'pub', 
    'bar', 'food_court', 'ice_cream', 'marketplace', 
    'stripclub', 'bistro', 'juice_bar']

# %%
food_df = places[places['amenity'].isin(food_list)]
food_df
# Out:
#              lat         lon                      timestamp     amenity  \
# 0      49.260812 -123.125736  2020-03-20T18:22:12.000-07:00        cafe
# 1      49.260953 -123.125704  2019-08-02T18:11:20.000-07:00   fast_food
# 13     49.126650 -123.182470  2020-03-30T09:08:51.000-07:00  restaurant
# 16     49.283192 -123.109050  2015-12-18T21:41:07.000-08:00         pub
# 19     49.265951 -123.246630  2011-11-19T08:06:36.000-08:00         pub
# ...          ...         ...                            ...         ...
# 17712  49.250408 -123.076261  2017-07-08T05:22:57.000-07:00  restaurant
# 17713  49.278424 -122.806704  2013-03-26T23:45:49.000-07:00        cafe
# 17714  49.278770 -122.797628  2013-03-26T23:45:49.000-07:00  restaurant
# 17716  49.282666 -122.826978  2019-09-13T13:56:49.000-07:00         pub
# 17717  49.282420 -122.826340  2019-09-13T13:56:49.000-07:00        cafe
#
#                            name  \
# 0                     Starbucks
# 1                    Salad Loop
# 13     Best Bite Indian Cuisine
# 16                   The Cambie
# 19              Mahony and Sons
# ...                         ...
# 17712            House of Dosas
# 17713          Creekside Coffee
# 17714                Togo Sushi
# 17716      Brown's Social House
# 17717          Gallagher's Cafe
#
#                                                     tags
# 0      {'brand:wikidata': 'Q37158', 'official_name': ...
# 1      {'opening_hours': 'Mo-Fr 07:00-17:00; Sa 10:00...
# 13     {'addr:housenumber': '10-3891', 'phone': '+1-6...
# 16     {'toilets:wheelchair': 'no', 'wheelchair': 'li...
# 19                                 {'wheelchair': 'yes'}
# ...                                                  ...
# 17712  {'addr:housenumber': '1391', 'phone': '+1-604-...
# 17713                                                 {}
# 17714                            {'cuisine': 'japanese'}
# 17716  {'addr:housenumber': '215', 'brewery': 'Guinne...
# 17717  {'addr:housenumber': '232', 'internet_access':...
#
# [5085 rows x 6 columns]

# %%
food_df = food_df.sort_values(by=['name'])
food_df.to_json('food-aminities-vancouver.json', orient='records', lines=True)

# %% [markdown]
# Making a separate list for places not in the set for further investigation

# %%
non_food_df = places[~places['amenity'].isin(food_list)]
non_food_df = non_food_df.sort_values(by=['amenity'])
non_food_df.to_json('non-food-aminities-vancouver.json', orient='records', lines=True)
