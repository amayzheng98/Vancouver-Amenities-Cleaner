# %%
from sklearn.cluster import KMeans
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# access all hotel locations
accomodations = pd.read_csv('HLLBC_ACC.csv')
accomodations = accomodations.filter(items=['NAME','DESCRIPTN','ADDRESS','LATITUDE','LONGITUDE'])
accomodations['DESCRIPTN'].unique()
# Out:
# array(['Campgrounds & RV Parks - Private;',
#        'Bed & Breakfasts; Campgrounds & RV Parks - Private;',
#        'Bed & Breakfasts;', 'Hotels & Motels;', 'Hostels;',
#        'Hotels & Motels; Resorts;',
#        'Cabins & Cottages; Campgrounds & RV Parks - Private;',
#        'Cabins & Cottages;', 'Bed & Breakfasts; Cabins & Cottages;',
#        'Hotels & Motels; Cabins & Cottages;',
#        'Hotels & Motels; Cabins & Cottages; Campgrounds & RV Parks - Private;',
#        'Vacation Rentals;', 'Resorts; Cabins & Cottages;',
#        'Hotels & Motels; Campgrounds & RV Parks - Private;',
#        'Resorts; Vacation Rentals; Cabins & Cottages; Campgrounds & RV Parks - Private;',
#        'Resorts;', 'Vacation Rentals; Cabins & Cottages;',
#        'Hotels & Motels; Hostels;',
#        'Hotels & Motels; Resorts; Vacation Rentals;',
#        'Hotels & Motels; Resorts; Cabins & Cottages; Campgrounds & RV Parks - Private;',
#        'Vacation Rentals; Cabins & Cottages; Campgrounds & RV Parks - Private;',
#        'Hotels & Motels; Vacation Rentals; Cabins & Cottages;',
#        'Resorts; Campgrounds & RV Parks - Private;',
#        'Resorts; Cabins & Cottages; Campgrounds & RV Parks - Private;',
#        'Hotels & Motels; Resorts; Cabins & Cottages;',
#        'Resorts; Vacation Rentals; Accommodation Management Companies;',
#        'Resorts; Vacation Rentals;',
#        'Accommodation Management Companies;',
#        'Hotels & Motels; Vacation Rentals;',
#        'Campgrounds & RV Parks - National or Provincial;',
#        'Bed & Breakfasts; Vacation Rentals;',
#        'Vacation Rentals; Campgrounds & RV Parks - Private;',
#        'Cabins & Cottages; Accommodation Management Companies;',
#        'Bed & Breakfasts; Vacation Rentals; Cabins & Cottages;',
#        'Hostels; Vacation Rentals;',
#        'Bed & Breakfasts; Cabins & Cottages; Campgrounds & RV Parks - Private;',
#        'Bed & Breakfasts; Hotels & Motels;'], dtype=object)

# %%
# filter to all the hotels, resorts, and bed & breakfasts
hotel_list = [
    'Bed & Breakfasts; Campgrounds & RV Parks - Private;', 
    'Bed & Breakfasts;', 'Hotels & Motels;','Hostels;', 
    'Hotels & Motels; Resorts;','Hotels & Motels; Cabins & Cottages;',
    'Hotels & Motels; Cabins & Cottages; Campgrounds & RV Parks - Private;',
    'Hotels & Motels; Campgrounds & RV Parks - Private;',
    'Resorts; Vacation Rentals; Cabins & Cottages; Campgrounds & RV Parks - Private;',
    'Resorts;','Hotels & Motels; Hostels;','Hotels & Motels; Resorts; Vacation Rentals;',
    'Hotels & Motels; Resorts; Cabins & Cottages; Campgrounds & RV Parks - Private;',
    'Hotels & Motels; Vacation Rentals; Cabins & Cottages;',
    'Resorts; Campgrounds & RV Parks - Private;',
    'Resorts; Cabins & Cottages; Campgrounds & RV Parks - Private;',
    'Hotels & Motels; Resorts; Cabins & Cottages;',
    'Resorts; Vacation Rentals; Accommodation Management Companies;',
    'Resorts; Vacation Rentals;',
    'Hotels & Motels; Vacation Rentals;',
    'Bed & Breakfasts; Vacation Rentals;',
    'Bed & Breakfasts; Vacation Rentals; Cabins & Cottages;',
    'Hostels; Vacation Rentals;',
    'Bed & Breakfasts; Cabins & Cottages; Campgrounds & RV Parks - Private;',
    'Bed & Breakfasts; Hotels & Motels;'
]

# %%
hotel_df = accomodations[accomodations['DESCRIPTN'].isin(hotel_list)]
hotel_df = hotel_df.rename(columns={'LATITUDE': 'lat', 'LONGITUDE': 'lon','NAME':'name','DESCRIPTN':'amenity','ADDRESS':'tags'})
hotel_df
# Out:
#                                                    name  \
# 2                  Caron Creek RV Park  & Riverview B&B
# 4                                           Caprice B&B
# 5     Hampton Inn & Suites by Hilton, Downtown Vanco...
# 6                     Ramada Limited Downtown Vancouver
# 7               Ocean Island Inn | Backpackers | Suites
# ...                                                 ...
# 1444            E'Laysa Guesthouse and Vineyard Retreat
# 1446                                    Hotel Kimberley
# 1447                       Howard Johnson Fort St. John
# 1449                                       Pilots' Loft
# 1452                           The Francis Boutique Inn
#
#                                                 amenity  \
# 2     Bed & Breakfasts; Campgrounds & RV Parks - Pri...
# 4                                     Bed & Breakfasts;
# 5                                      Hotels & Motels;
# 6                                      Hotels & Motels;
# 7                                              Hostels;
# ...                                                 ...
# 1444                                  Bed & Breakfasts;
# 1446                                   Hotels & Motels;
# 1447                                   Hotels & Motels;
# 1449                                  Bed & Breakfasts;
# 1452                                   Hotels & Motels;
#
#                                        tags        lat         lon
# 2                7545 Hwy 97S, Chetwynd, BC  55.619951 -121.814346
# 4          1111 Gower Point Rd, Gibsons, BC  49.386438 -123.530209
# 5              111 Robson St, Vancouver, BC  49.277779 -123.114212
# 6            435 Pender St W, Vancouver, BC  49.283282 -123.112543
# 7             791 Pandora Ave, Victoria, BC  48.427968 -123.364059
# ...                                     ...        ...         ...
# 1444  1056 Corbishley Avenue, Penticton, BC  49.520042 -119.570205
# 1446    300 Wallinger Avenue, Kimberley, BC  49.684565 -115.983007
# 1447    8540 Alaska Road, Fort St. John, BC  56.229501 -120.820567
# 1449      1408 Highlands Blvd., Agassiz, BC  49.231028 -121.910758
# 1452        1536 Peninsula Rd, Ucluelet, BC  48.940654 -125.545603
#
# [870 rows x 5 columns]

# %%
hotel_df.to_json('vancouver-hotels.json', orient='records', lines=True)
